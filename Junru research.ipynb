# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#import gender_guesser.detector as gender
from collections import Counter

# %%
dmi_1998 = pd.read_csv('DMI.1998.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
dmi_1999 = pd.read_csv('DMI.1999.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')

# %%
dmi_2000 = pd.read_csv('DMI.2000.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
dmi_2001 = pd.read_csv('DMI.2001.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')

# %%
dmi_2002 = pd.read_csv('DMI.2002.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
dmi_2003 = pd.read_csv('DMI.2003.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')

# %%
dmi_2004 = pd.read_csv('DMI.2004.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')

# %%
dmi_2005 = pd.read_csv('DMI.2005.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
dmi_2006 = pd.read_csv('DMI.2006.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')

# %%
#dmi_2007 = pd.read_csv('DMI.2007.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
dmi_2008 = pd.read_csv('DMI.2008.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')

# %%
#dmi_2009 = pd.read_csv('DMI.2009.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
dmi_2010 = pd.read_csv('DMI.2010.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')

# %%
dmi_2011 = pd.read_csv('DMI.2011.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
dmi_2012 = pd.read_csv('DMI.2012.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')

# %%
dmi_2013 = pd.read_csv('DMI.2013.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
dmi_2014 = pd.read_csv('DMI.2014.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')

# %%
dmi_2015 = pd.read_csv('DMI.2015.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
dmi_2016 = pd.read_csv('DMI.2016.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')

# %%
dmi_2017 = pd.read_csv('DMI.2017.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
dmi_2018 = pd.read_csv('DMI.2018.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')

# %%
dmi_2019 = pd.read_csv('DMI.2019.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
dmi_2020 = pd.read_csv('DMI.2020.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 9
#       7 dmi_2004 = pd.read_csv('DMI.2004.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
#       8 dmi_2005 = pd.read_csv('DMI.2005.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
# ----> 9 dmi_2006 = pd.read_csv('DMI.2006.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
#      10 #dmi_2007 = pd.read_csv('DMI.2007.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
#      11 dmi_2008 = pd.read_csv('DMI.2008.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
#
# ...

# %%
year_list = np.arange(1998,2020)
curr_file = 0
next_file = 0 
list_of_entries_amount = []
list_of_overturn_amount = []
list_of_year_midpoint = []
for i in year_list:
    curr_file = pd.read_csv('DMI.' + str(i) + '.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
    next_file = pd.read_csv('DMI.' + str(i+1) + '.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
    temp_merge_inner = pd.merge(curr_file,next_file, on='DUNSNO',how='inner')
    temp_merge_inner['mismatch_indicator'] = np.where(temp_merge_inner['PRINCIPAL_x'] != temp_merge_inner['PRINCIPAL_y'], 1, 0)
    list_of_entries_amount.append(len(temp_merge_inner['mismatch_indicator']))
    list_of_overturn_amount.append(sum(temp_merge_inner['mismatch_indicator']))
    #list_of_year_midpoint.append(year_list[i]+0.5)
    print(i)
# Out:
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 9
#       7 for i in year_list:
#       8     curr_file = pd.read_csv('DMI.' + str(i) + '.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
# ----> 9     next_file = pd.read_csv('DMI.' + str(i+1) + '.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
#      10     temp_merge_inner = pd.merge(curr_file,next_file, on='DUNSNO',how='inner')
#      11     temp_merge_inner['mismatch_indicator'] = np.where(temp_merge_inner['PRINCIPAL_x'] != temp_merge_inner['PRINCIPAL_y'], 1, 0)
#
# ...

# %%
#list_of_t_df = [#put DUNSNO dataframes in here, make sure PRINCIPAL and DUNSNO KEY are in it]
#list_of_years = np.arange(#first year, last year + 1)
#list_of_entries_amount = []
#list_of_overturn_amount = []
#list_of_year_midpoint = []
#for i in range(len(list_of_t_df)-1):
    temp_merge_inner = pd.merge(list_of_t_df[i],list_of_t_df[i+1], on='DUNSNO',how='inner')
    temp_merge_inner['mismatch_indicator'] = np.where(temp_merge_inner['PRINCIPAL_x'] != temp_merge_inner['PRINCIPAL_y'], 1, 0)
    list_of_entries_amount.append(len(temp_merge_inner['mismatch_indicator']))
    list_of_overturn_amount.append(sum(temp_merge_inner['mismatch_indicator']))
    list_of_year_midpoint.append(list_of_years[i]+0.5)

# %%
#plotting number of overtruns vs midpoint year
plt.plot(list_of_year_midpoint, list_of_overturn_amount, marker='o')
plt.title('Year Midpoint vs Overturn Amount')
plt.xlabel('Year Midpoint')
plt.ylabel('Overturn Amount')
#plt.xticks(list_of_year_midpoint)
plt.grid(True)
plt.show()

# %%
#plotting % overturns vs midpoint year
overturn_per_entry = [o/e if e != 0 else 0 for o, e in zip(list_of_overturn_amount, list_of_entries_amount)]
plt.plot(list_of_year_midpoint, overturn_per_entry, marker='o')
plt.title('Year Midpoint vs Overturn Ratio')
plt.xlabel('Year Midpoint')
plt.ylabel('Overturn Amount')
plt.xticks(list_of_year_midpoint)
plt.grid(True)
plt.show()

# %%
list_of_overturn_amount
# Out:
# [161637,
#  94589,
#  748109,
#  1059002,
#  1628029,
#  1552883,
#  798164,
#  1350158,
#  1319649,
#  931462,
#  1622365,
#  1136371,
#  2383355,
#  575976,
#  1131750,
#  1816299,
#  371258]

# %%
list_of_entries_amount
# Out:
# [1547642,
#  1392504,
#  10841957,
#  15550419,
#  17150235,
#  17496197,
#  17850974,
#  20043787,
#  16830767,
#  16895963,
#  19525997,
#  19597577,
#  24637225,
#  24641596,
#  24130223,
#  22498861,
#  20612896]

# %%
year_list = np.arange(2015,2017)
curr_file = 0
next_file = 0 
list_of_entries_amount_part_3 = []
list_of_overturn_amount_part_3 = []
list_of_year_midpoint = []
for i in year_list:
    curr_file = pd.read_csv('DMI.' + str(i) + '.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
    next_file = pd.read_csv('DMI.' + str(i+1) + '.CSV', usecols=['YEAR','DUNSNO','PRINCIPAL'], quoting =3, on_bad_lines='skip')
    temp_merge_inner = pd.merge(curr_file,next_file, on='DUNSNO',how='inner')
    temp_merge_inner['mismatch_indicator'] = np.where(temp_merge_inner['PRINCIPAL_x'] != temp_merge_inner['PRINCIPAL_y'], 1, 0)
    list_of_entries_amount_part_3.append(len(temp_merge_inner['mismatch_indicator']))
    list_of_overturn_amount_part_3.append(sum(temp_merge_inner['mismatch_indicator']))
    #list_of_year_midpoint.append(year_list[i]+0.5)
    print(i)
# Out:
# 2015
# 2016

# %%
list_of_entries_amount_part_3
# Out:
# [20209344, 19390106]

# %%
list_of_overturn_amount_part_1 = [161637,
 94589,
 748109,
 1059002,
 1628029,
 1552883,
 798164,
 1350158,
 1319649,
 931462,
 1622365,
 1136371,
 2383355,
 575976,
 1131750,
 1816299,
 371258]

# %%
list_of_entries_amount_part_1 = [1547642,
 1392504,
 10841957,
 15550419,
 17150235,
 17496197,
 17850974,
 20043787,
 16830767,
 16895963,
 19525997,
 19597577,
 24637225,
 24641596,
 24130223,
 22498861,
 20612896]

# %%
list_of_entries_amount_part_2 = [20473727, 22995934, 27465601]

# %%
list_of_overturn_amount_part_2 = [397419, 340355, 195169]

# %%
chart_year_points = np.arange(1998,2020)
chart_year_points = [i for i in chart_year_points]
chart_year_points
# Out:
# [1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019]

# %%
len(list_of_entries_amount_part_1) + len(list_of_entries_amount_part_2)
# Out:
# 20

# %%
len(chart_year_points)
# Out:
# 22

# %%
total_list_entries = list_of_entries_amount_part_1 + list_of_entries_amount_part_3 + list_of_entries_amount_part_2
total_list_overturn = list_of_overturn_amount_part_1 + list_of_overturn_amount_part_3 + list_of_overturn_amount_part_2

# %%
total_list_entries
# Out:
# [1547642,
#  1392504,
#  10841957,
#  15550419,
#  17150235,
#  17496197,
#  17850974,
#  20043787,
#  16830767,
#  16895963,
#  19525997,
#  19597577,
#  24637225,
#  24641596,
#  24130223,
#  22498861,
#  20612896,
#  20209344,
#  19390106,
#  20473727,
#  22995934,
#  27465601]

# %%
total_list_overturn
# Out:
# [161637,
#  94589,
#  748109,
#  1059002,
#  1628029,
#  1552883,
#  798164,
#  1350158,
#  1319649,
#  931462,
#  1622365,
#  1136371,
#  2383355,
#  575976,
#  1131750,
#  1816299,
#  371258,
#  342378,
#  532509,
#  397419,
#  340355,
#  195169]

# %%
plt.plot(chart_year_points, total_list_overturn, marker='o')
plt.title('Year Midpoint vs Overturn Amount')
plt.xlabel('Year Midpoint')
plt.ylabel('Overturn Amount')
#plt.xticks(list_of_year_midpoint)
plt.grid(True)
plt.show()

# %%
overturn_per_entry = [o/e if e != 0 else 0 for o, e in zip(total_list_overturn, total_list_entries)]
plt.plot(chart_year_points, overturn_per_entry, marker='o')
plt.title('Year Midpoint vs Overturn Ratio')
plt.xlabel('Year Midpoint')
plt.ylabel('Overturn Amount')
plt.xticks(chart_year_points[::4])
plt.grid(True)
plt.show()

# %%
list_of_entries_amount_part_3
list_of_overturn_amount_part_3
# Out:
# [342378, 532509]

# %%
total_list_overturn,
# Out:
# ([161637,
#   94589,
#   748109,
#   1059002,
#   1628029,
#   1552883,
#   798164,
#   1350158,
#   1319649,
#   931462,
#   1622365,
#   1136371,
#   2383355,
#   575976,
#   1131750,
#   1816299,
#   371258,
#   342378,
#   532509,
#   397419,
#   340355,
#   195169],)

# %%
total_list_overturn
# Out:
# [161637,
#  94589,
#  748109,
#  1059002,
#  1628029,
#  1552883,
#  798164,
#  1350158,
#  1319649,
#  931462,
#  1622365,
#  1136371,
#  2383355,
#  575976,
#  1131750,
#  1816299,
#  371258,
#  342378,
#  532509,
#  397419,
#  340355,
#  195169]

# %%
#save plots to dropbox
